# %% [markdown]
# ## Import functions

# %%
# import all functions from functions.py
from functions import *

# %% [markdown]
# ## Recipe Recommender

# %%
main()
# Out:
# On a scale of 1 to 5, how open are you to trying different cuisines?
# 1: Not open at all
# 2: Slightly open
# 3: Moderately open
# 4: Very open
# 5: Extremely open
#
# Would you like to provide your own ingredients? (yes/no)
#
# Using random ingredients: ['olive oil', 'chicken drumstick', 'beef', 'parsley', 'salmon', 'bacon', 'sugar', 'onion', 'garlic', 'tomato', 'mayonnaise', 'cucumber', 'lemon', 'yogurt', 'pepper', 'eggplant', 'milk', 'lamb', 'chili', 'potato', 'carrot', 'cabbage', 'broccoli', 'lettuce']
#
# The ingredients you have are similar to the ingredients used in greek cuisine.
#
# Ingredients with Expiration Dates:
#                   Expiration_Date  Days_Left
# Ingredient
# lettuce                2024-06-01          0
# mayonnaise             2024-06-01          0
# broccoli               2024-06-02          1
# chicken drumstick      2024-06-03          2
# carrot                 2024-06-04          3
# salmon                 2024-06-05          4
# ...
